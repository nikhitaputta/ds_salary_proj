# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head(5)
# Out:
#                                         Company Name             Competitors  \
# 0                        Rubikloud Technologies\n3.7                      -1
# 1                                    Home Trust\n3.1                      -1
# 2                                   realtor.com\n2.7  Zillow, Trulia, Redfin
# 3  Langan Engineering and Environmental Services\...                      -1
# 4                                      Sonatype\n4.7                      -1
#
#    Founded     Headquarters                                 Industry  \
# 0     2013  Toronto, Canada  Enterprise Software & Network Solutions
# 1     1977  Toronto, Canada                                  Lending
# 2     1993  Santa Clara, CA                                 Internet
# 3     1970   Parsippany, NJ     Architectural & Engineering Services
# 4     2008       Fulton, MD             Computer Hardware & Software
#
#                                      Job Description  \
# 0  What We Are Building:\n\nAt Rubikloud, we are ...
# 1  Company Profile\n\nHome Capital Group Inc., to...
# 2  At realtor.com, we process terabytes of data e...
# 3  Work for an Industry Leader\nOutstanding Oppor...
# 4  We are 350+ employees from diverse backgrounds...
#
#                                            Job Title   Location  Rating  \
# 0                                     Data Scientist    Toronto     3.7
# 1                                     Data Scientist    Toronto     3.1
# 2                               Staff Data Scientist  Vancouver     2.7
# 3  Environmental Scientist or Biologist - 5 to 10...    Calgary     4.0
# 4  Backend Engineer Data Team - 100% Remote - Canada     Canada     4.7
#
#                     Revenue  ... same_location age python_yn tableau_yn  \
# 0  Unknown / Non-Applicable  ...             1   7         1          0
# 1  ₹10 to ₹50 billion (INR)  ...             1  43         1          0
# 2  Unknown / Non-Applicable  ...             0  27         1          0
# 3  ₹10 to ₹50 billion (INR)  ...             0  50         0          0
# 4   ₹5 to ₹10 billion (INR)  ...             0  12         0          0
#
#    aws_yn  spark_yn  computer_science_yn ml_yn sql_yn  excel_yn
# 0       0         1                    1     1      1         0
# 1       0         1                    0     0      0         1
# 2       0         1                    1     1      1         1
# 3       0         0                    0     0      0         1
# 4       1         1                    1     0      0         0
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['Company Name', 'Competitors', 'Founded', 'Headquarters', 'Industry',
#        'Job Description', 'Job Title', 'Location', 'Rating', 'Revenue',
#        'Salary Estimate', 'Sector', 'Size', 'Type of ownership', 'min_salary',
#        'max_salary', 'avg_salary', 'company', 'headquarters_location',
#        'same_location', 'age', 'python_yn', 'tableau_yn', 'aws_yn', 'spark_yn',
#        'computer_science_yn', 'ml_yn', 'sql_yn', 'excel_yn'],
#       dtype='object')

# %%
## Job title and seniority 
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['title'] = df['Job Title'].apply(title_simplifier)
df.title.value_counts()
# Out:
# na                211
# analyst           164
# data engineer     138
# data scientist    134
# mle                36
# manager            26
# director            9
# Name: title, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        529
# senior    187
# jr          2
# Name: seniority, dtype: int64

# %%
##  Fix Location Canada

df['Location'] = df.Location.apply(lambda x: x if x.lower() != 'canada' else 'na')
df.Location.value_counts()
# Out:
# Toronto                 191
# Montreal                106
# Vancouver               103
# Mississauga              39
# Ottawa                   39
# Calgary                  28
# Burnaby                  11
# Markham                  11
# Brampton                 10
# Edmonton                 10
# Welwyn                   10
# Waterloo                  9
# Ontario                   8
# Laval                     8
# na                        8
# Winnipeg                  7
# Kitchener                 7
# Chalk River               6
# Kingston                  5
# Richmond                  5
# Victoria                  5
# Saint-Laurent             5
# Oakville                  4
# London                    4
# Saskatoon                 4
# Guelph                    4
# Cochin                    4
# Halifax                   3
# Cambridge                 3
# Fort St. John             3
#                        ...
# White Rock                1
# Burlington                1
# Leamington                1
# New Westminster           1
# Vaughan                   1
# Moncton                   1
# Candiac                   1
# British Columbia          1
# Montréal-Est              1
# Souris                    1
# Whitby                    1
# Saint-Jérôme              1
# Hamilton                  1
# Charlottetown             1
# New Denver                1
# Coquitlam                 1
# Windsor                   1
# Kirkland                  1
# Maple Ridge               1
# Senneville                1
# Saanichton                1
# Pickering                 1
# Saint-Hubert              1
# Newmarket                 1
# Stratford                 1
# Upper Canada Village      1
# Concord                   1
# Kindersley                1
# West Vancouver            1
# Kanata                    1
# Name: Location, Length: 75, dtype: int64

# %%
##  Job description length 
df['job_desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['job_desc_len']
# Out:
# 0      3707
# 1      3274
# 2      3284
# 3      3571
# 4      3954
# 5      3964
# 6      4813
# 7      9208
# 8      3998
# 9      3181
# 10     4336
# 11     3582
# 12     4055
# 13     3025
# 14     4556
# 15     8435
# 16     5216
# 17     3991
# 18     7581
# 19     3582
# 20     5026
# 21     5578
# 22     4466
# 23     1387
# 24     5832
# 25     3714
# 26     3679
# 27     1322
# 28     2889
# 29     3480
#        ...
# 688    3798
# 689    6254
# 690    3515
# 691    5144
# 692    5270
# 693    4109
# 694    5160
# 695    4376
# 696    5920
# 697    4493
# 698    8884
# 699    6461
# 700    4894
# 701    9466
# 702    4583
# 703    5046
# 704    2904
# 705    8453
# 706    5770
# 707    5846
# 708    4206
# 709    4051
# 710    5513
# 711    7537
# 712    2397
# 713    3596
# 714    3499
# 715    5176
# 716    1717
# 717    2122
# Name: job_desc_len, Length: 718, dtype: int64

# %%
##  Competitor count

df['comp_count'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)
df['comp_count']
# Out:
# 0      0
# 1      0
# 2      3
# 3      0
# 4      0
# 5      0
# 6      3
# 7      0
# 8      3
# 9      0
# 10     0
# 11     0
# 12     0
# 13     0
# 14     3
# 15     0
# 16     0
# 17     3
# 18     2
# 19     0
# 20     0
# 21     0
# 22     0
# 23     0
# 24     0
# 25     0
# 26     0
# 27     0
# 28     3
# 29     0
#       ..
# 688    0
# 689    3
# 690    3
# 691    0
# 692    0
# 693    0
# 694    0
# 695    0
# 696    2
# 697    2
# 698    3
# 699    0
# 700    0
# 701    0
# 702    0
# 703    0
# 704    0
# 705    0
# 706    3
# 707    3
# 708    0
# 709    0
# 710    0
# 711    3
# 712    0
# 713    3
# 714    0
# 715    0
# 716    0
# 717    0
# Name: comp_count, Length: 718, dtype: int64

# %%
df.columns
# Out:
# Index(['Company Name', 'Competitors', 'Founded', 'Headquarters', 'Industry',
#        'Job Description', 'Job Title', 'Location', 'Rating', 'Revenue',
#        'Salary Estimate', 'Sector', 'Size', 'Type of ownership', 'min_salary',
#        'max_salary', 'avg_salary', 'company', 'headquarters_location',
#        'same_location', 'age', 'python_yn', 'tableau_yn', 'aws_yn', 'spark_yn',
#        'computer_science_yn', 'ml_yn', 'sql_yn', 'excel_yn', 'title',
#        'seniority', 'job_desc_len', 'comp_count'],
#       dtype='object')

# %%
#remove new line from job title
df['company'] = df['company'].apply(lambda x: x.replace('\n',''))
df['company']
# Out:
# 0                             Rubikloud Technologies
# 1                                         Home Trust
# 2                                        realtor.com
# 3      Langan Engineering and Environmental Services
# 4                                           Sonatype
# 5                             Rubikloud Technologies
# 6                                                TWG
# 7                                              Uni3T
# 8                                             Syniti
# 9                                              Asana
# 10                                           auticon
# 11                                              Citi
# 12                                      Jungle Scout
# 13                                     SkipTheDishes
# 14                                            Amazon
# 15                               Precision Nutrition
# 16                                      Label Engine
# 17                                               RBC
# 18                            Suncor Energy Services
# 19                                          Citibank
# 20                                   The Headhunters
# 21                                           Interac
# 22                                           Interac
# 23                           Evidence Partners, Inc.
# 24            Canadian Security Intelligence Service
# 25                                     Thrive Health
# 26                            IFG Project Resourcing
# 27                                         Clearbanc
# 28                                   Electronic Arts
# 29                             Behaviour Interactive
#                            ...
# 688                                     Next Pathway
# 689                               McKinsey & Company
# 690                     Eagle Professional Resources
# 691                              Eurofins Scientific
# 692                                 Custom Biologics
# 693                                    StackPros Inc
# 694                        Eurofins Canada BioPharma
# 695                                         Finastra
# 696                                  Parmalat Canada
# 697                                           Sanofi
# 698                                           Nuance
# 699                                        CannTrust
# 700                        Eurofins Canada BioPharma
# 701                                       Element AI
# 702                                 Custom Biologics
# 703                              Eurofins Scientific
# 704                                 Util-Assist Inc.
# 705                                        Genentech
# 706                                           Amazon
# 707                                            AECOM
# 708                     Process Automation Solutions
# 709                                     CI Financial
# 710                                           Symend
# 711                                            Roche
# 712                        Aether Catalyst Solutions
# 713                                  Electronic Arts
# 714                                        AIR MILES
# 715                             matrix solutions inc
# 716                           BIOPHARMA SERVICES INC
# 717                                  SoundHound Inc.
# Name: company, Length: 718, dtype: object

# %%
df.describe()
# Out:
#            Founded      Rating  min_salary  max_salary  avg_salary  \
# count   718.000000  718.000000  718.000000  718.000000  718.000000
# mean   1366.651811    3.150557   73.864903  100.715877   87.290390
# std     913.595860    1.733481   26.252499   27.372528   26.150919
# min      -1.000000   -1.000000   44.000000   64.000000   55.500000
# 25%      -1.000000    3.100000   54.250000   82.500000   69.125000
# 50%    1974.000000    3.700000   70.000000  102.000000   86.000000
# 75%    2004.000000    4.000000   87.000000  110.000000   95.500000
# max    2020.000000    5.000000  168.000000  198.000000  183.000000
#
#        same_location         age   python_yn  tableau_yn      aws_yn  \
# count     718.000000  718.000000  718.000000  718.000000  718.000000
# mean        0.367688   30.977716    0.545961    0.153203    0.201950
# std         0.482512   47.051941    0.498230    0.360434    0.401735
# min         0.000000   -1.000000    0.000000    0.000000    0.000000
# 25%         0.000000   -1.000000    0.000000    0.000000    0.000000
# 50%         0.000000   14.000000    1.000000    0.000000    0.000000
# 75%         1.000000   34.000000    1.000000    0.000000    0.000000
# max         1.000000  226.000000    1.000000    1.000000    1.000000
#
#          spark_yn  computer_science_yn       ml_yn      sql_yn    excel_yn  \
# count  718.000000           718.000000  718.000000  718.000000  718.000000
# mean     0.267409             0.410864    0.380223    0.486072    0.495822
# std      0.442916             0.492334    0.485780    0.500154    0.500331
# min      0.000000             0.000000    0.000000    0.000000    0.000000
# 25%      0.000000             0.000000    0.000000    0.000000    0.000000
# 50%      0.000000             0.000000    0.000000    0.000000    0.000000
# 75%      1.000000             1.000000    1.000000    1.000000    1.000000
# max      1.000000             1.000000    1.000000    1.000000    1.000000
#
#        job_desc_len  comp_count
# count    718.000000  718.000000
# mean    4049.796657    0.803621
# std     2056.988999    1.297627
# min       67.000000    0.000000
# 25%     2759.000000    0.000000
# 50%     3707.500000    0.000000
# 75%     4848.000000    2.000000
# max    18258.000000    3.000000

# %%
df.Rating.hist()

# %%
df.head()
# Out:
#                                         Company Name             Competitors  \
# 0                        Rubikloud Technologies\n3.7                      -1
# 1                                    Home Trust\n3.1                      -1
# 2                                   realtor.com\n2.7  Zillow, Trulia, Redfin
# 3  Langan Engineering and Environmental Services\...                      -1
# 4                                      Sonatype\n4.7                      -1
#
#    Founded     Headquarters                                 Industry  \
# 0     2013  Toronto, Canada  Enterprise Software & Network Solutions
# 1     1977  Toronto, Canada                                  Lending
# 2     1993  Santa Clara, CA                                 Internet
# 3     1970   Parsippany, NJ     Architectural & Engineering Services
# 4     2008       Fulton, MD             Computer Hardware & Software
#
#                                      Job Description  \
# 0  What We Are Building:\n\nAt Rubikloud, we are ...
# 1  Company Profile\n\nHome Capital Group Inc., to...
# 2  At realtor.com, we process terabytes of data e...
# 3  Work for an Industry Leader\nOutstanding Oppor...
# 4  We are 350+ employees from diverse backgrounds...
#
#                                            Job Title   Location  Rating  \
# 0                                     Data Scientist    Toronto     3.7
# 1                                     Data Scientist    Toronto     3.1
# 2                               Staff Data Scientist  Vancouver     2.7
# 3  Environmental Scientist or Biologist - 5 to 10...    Calgary     4.0
# 4  Backend Engineer Data Team - 100% Remote - Canada         na     4.7
#
#                     Revenue  ... aws_yn spark_yn computer_science_yn ml_yn  \
# 0  Unknown / Non-Applicable  ...      0        1                   1     1
# 1  ₹10 to ₹50 billion (INR)  ...      0        1                   0     0
# 2  Unknown / Non-Applicable  ...      0        1                   1     1
# 3  ₹10 to ₹50 billion (INR)  ...      0        0                   0     0
# 4   ₹5 to ₹10 billion (INR)  ...      1        1                   1     0
#
#    sql_yn  excel_yn           title seniority job_desc_len  comp_count
# 0       1         0  data scientist        na         3707           0
# 1       0         1  data scientist        na         3274           0
# 2       1         1  data scientist        na         3284           3
# 3       0         1              na        na         3571           0
# 4       0         0              na        na         3954           0
#
# [5 rows x 33 columns]

# %%
df.avg_salary.hist()

# %%
df.age.hist()

# %%
df.job_desc_len.hist()

# %%
df.boxplot(column = ['Rating'])

# %%
df.boxplot(column = ['job_desc_len'])

# %%
df.boxplot(column = ['age','avg_salary'])

# %%
df[['age','avg_salary','Rating','job_desc_len']].corr()
# Out:
#                    age  avg_salary    Rating  job_desc_len
# age           1.000000   -0.081019  0.236076      0.156046
# avg_salary   -0.081019    1.000000 -0.076126      0.106217
# Rating        0.236076   -0.076126  1.000000      0.130009
# job_desc_len  0.156046    0.106217  0.130009      1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','avg_salary','Rating','job_desc_len','comp_count']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
cmap=sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %%
df.columns
# Out:
# Index(['Company Name', 'Competitors', 'Founded', 'Headquarters', 'Industry',
#        'Job Description', 'Job Title', 'Location', 'Rating', 'Revenue',
#        'Salary Estimate', 'Sector', 'Size', 'Type of ownership', 'min_salary',
#        'max_salary', 'avg_salary', 'company', 'headquarters_location',
#        'same_location', 'age', 'python_yn', 'tableau_yn', 'aws_yn', 'spark_yn',
#        'computer_science_yn', 'ml_yn', 'sql_yn', 'excel_yn', 'title',
#        'seniority', 'job_desc_len', 'comp_count'],
#       dtype='object')

# %%
df_cat = df[['Location','headquarters_location', 'Size', 'Type of ownership', 'Industry','Sector','Revenue'
             ,'same_location','python_yn','tableau_yn','aws_yn','spark_yn','computer_science_yn', 
             'ml_yn','sql_yn','excel_yn','title','seniority']]

# %%
sns.set(rc={'figure.figsize':(20,5)})
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 75
# graph for headquarters_location: total = 149
# graph for Size: total = 9
# graph for Type of ownership: total = 13
# graph for Industry: total = 65
# graph for Sector: total = 24
# graph for Revenue: total = 13
# /Users/nikhitaputta/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8377 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/nikhitaputta/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 8377 missing from current font.
#   font.set_text(s, 0, flags=flags)
# graph for company: total = 475
# graph for same_location: total = 2
# graph for python_yn: total = 2
# graph for tableau_yn: total = 2
# graph for aws_yn: total = 2
# graph for spark_yn: total = 2
# graph for computer_science_yn: total = 2
# graph for ml_yn: total = 2
# graph for sql_yn: total = 2
# graph for excel_yn: total = 2
# graph for title: total = 7
# graph for seniority: total = 3

# %%
for i in df_cat[['Location','headquarters_location','company']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for headquarters_location: total = 20
# graph for company: total = 20

# %%
df.columns
# Out:
# Index(['Company Name', 'Competitors', 'Founded', 'Headquarters', 'Industry',
#        'Job Description', 'Job Title', 'Location', 'Rating', 'Revenue',
#        'Salary Estimate', 'Sector', 'Size', 'Type of ownership', 'min_salary',
#        'max_salary', 'avg_salary', 'company', 'headquarters_location',
#        'same_location', 'age', 'python_yn', 'tableau_yn', 'aws_yn', 'spark_yn',
#        'computer_science_yn', 'ml_yn', 'sql_yn', 'excel_yn', 'title',
#        'seniority', 'job_desc_len', 'comp_count'],
#       dtype='object')

# %%
pd.pivot_table(df, index = 'title', values = 'avg_salary')
# Out:
#                 avg_salary
# title
# analyst          83.939024
# data engineer    86.452899
# data scientist   86.832090
# director         93.222222
# manager          97.096154
# mle              87.819444
# na               89.182464

# %%
pd.pivot_table(df, index = ['title','seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# title          seniority
# analyst        na          84.806569
#                senior      79.537037
# data engineer  na          87.095745
#                senior      85.079545
# data scientist jr          74.000000
#                na          91.064706
#                senior      79.604167
# director       na          92.785714
#                senior      94.750000
# manager        na          97.270833
#                senior      95.000000
# mle            na          87.465517
#                senior      89.285714
# na             jr          72.500000
#                na          88.993464
#                senior      89.982456

# %%
pd.pivot_table(df, index = ['Location','title'], values = 'avg_salary').sort_values(['title','avg_salary'], ascending = True)
# Out:
#                           avg_salary
# Location         title
# Hamilton         analyst   56.000000
# Saint-Jérôme     analyst   56.000000
# West Vancouver   analyst   56.000000
# Kingston         analyst   63.500000
# Stratford        analyst   63.500000
# Winnipeg         analyst   64.000000
# Burnaby          analyst   64.250000
# Saskatoon        analyst   72.500000
# Waterloo         analyst   72.500000
# Ontario          analyst   73.500000
# Carp             analyst   74.000000
# Edmonton         analyst   74.000000
# Etobicoke        analyst   74.000000
# Montréal-Est     analyst   74.000000
# North Vancouver  analyst   74.000000
# Guelph           analyst   75.000000
# Halifax          analyst   75.500000
# Richmond         analyst   75.500000
# Brampton         analyst   76.500000
# Kitchener        analyst   78.250000
# Burlington       analyst   79.000000
# Chatham          analyst   79.000000
# London           analyst   79.000000
# Saint-Hubert     analyst   79.000000
# Ottawa           analyst   79.785714
# Montreal         analyst   82.500000
# Mississauga      analyst   83.857143
# Victoria         analyst   84.500000
# Toronto          analyst   85.681818
# Vancouver        analyst   86.326087
# ...                              ...
# Kingston         na        79.250000
# Ottawa           na        79.625000
# London           na        80.500000
# Mississauga      na        84.200000
# Ontario          na        84.333333
# Chalk River      na        84.750000
# Dartmouth        na        86.000000
# na               na        86.400000
# Markham          na        86.500000
# Burnaby          na        87.375000
# Montreal         na        87.483871
# Vancouver        na        87.552632
# Greenfield       na        89.750000
# Brossard         na        90.500000
# Whitby           na        90.500000
# Guelph           na        95.000000
# Saanichton       na        95.000000
# Laval            na        95.833333
# Richmond         na        96.000000
# Toronto          na        96.458333
# Kirkland         na        99.000000
# British Columbia na       103.500000
# Kelowna          na       103.500000
# New Westminster  na       103.500000
# Senneville       na       103.500000
# Thorold          na       103.500000
# Candiac          na       112.500000
# Edmonton         na       113.600000
# Calgary          na       124.166667
# Vaughan          na       183.000000
#
# [159 rows x 1 columns]

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index = ['Location','title'], values = 'avg_salary', aggfunc = 'count').sort_values('Location', ascending = False)
# Out:
#                                      avg_salary
# Location             title
# na                   na                       5
#                      data scientist           1
#                      data engineer            1
#                      analyst                  1
# Winnipeg             analyst                  1
#                      na                       4
#                      data scientist           1
#                      data engineer            1
# Windsor              data scientist           1
# White Rock           na                       1
# Whitby               na                       1
# West Vancouver       analyst                  1
# Welwyn               na                       4
#                      manager                  1
#                      director                 2
#                      data scientist           3
# Waterloo             data engineer            2
#                      analyst                  1
#                      na                       1
#                      data scientist           5
# Victoria             na                       2
#                      data scientist           1
#                      analyst                  2
# Vaughan              na                       1
# Vancouver            na                      19
#                      mle                      8
#                      manager                  5
#                      director                 1
#                      data scientist          19
#                      data engineer           28
#                      analyst                 23
# Upper Canada Village analyst                  1
# Toronto              director                 3
#                      data engineer           51
#                      data scientist          40
#                      analyst                 33
#                      manager                  7
#                      na                      48
#                      mle                      9
# Thorold              na                       1
#                      data scientist           1
# Stratford            analyst                  1
# Souris               director                 1
# Senneville           na                       1
# Sault Ste. Marie     na                       2
# Saskatoon            data scientist           1
#                      analyst                  1
#                      na                       2
# Saint-Laurent        na                       5
# Saint-Jérôme         analyst                  1
# Saint-Hubert         analyst                  1
# Saanichton           na                       1
# Richmond Hill        mle                      1
#                      data scientist           1
# Richmond             analyst                  2
#                      na                       3
# Regina               analyst                  2
# Quebec               data engineer            1
#                      data scientist           1
# Pickering            data scientist           1
# Ottawa               analyst                  7
#                      na                       8
#                      mle                      3
#                      manager                  2
#                      director                 2
#                      data scientist          11
#                      data engineer            6
# Ontario              data scientist           1
#                      analyst                  3
#                      na                       3
#                      manager                  1
# Oakville             na                       3
#                      analyst                  1
# North Vancouver      na                       1
#                      analyst                  1
# Newmarket            analyst                  1
# New Westminster      na                       1
# New Denver           data scientist           1
# Montréal-Est         analyst                  1
# Montreal             na                      31
#                      mle                      7
#                      manager                  3
#                      data scientist          20
#                      data engineer           21
#                      analyst                 24
# Moncton              analyst                  1
# Mississauga          manager                  5
#                      analyst                 14
#                      data engineer            5
#                      data scientist           3
#                      mle                      2
#                      na                      10
# Mirabel              analyst                  2
# Markham              na                       5
#                      data scientist           4
#                      data engineer            1
#                      analyst                  1
# Maple Ridge          analyst                  1
# London               mle                      1
#                      analyst                  1
#                      na                       2
# Leamington           na                       1
# Laval                na                       6
#                      data engineer            2
# Kitchener            na                       1
#                      mle                      2
#                      data engineer            2
#                      analyst                  2
# Kirkland             na                       1
# Kingston             na                       2
#                      data scientist           1
#                      analyst                  2
# Kindersley           na                       1
# Kelowna              na                       2
# Kanata               na                       1
# Hamilton             analyst                  1
# Halifax              data scientist           1
#                      analyst                  2
# Guelph               analyst                  3
#                      na                       1
# Greenfield           na                       2
# Fort St. John        na                       3
# Etobicoke            manager                  1
#                      analyst                  1
# Edmonton             analyst                  1
#                      na                       5
#                      data scientist           1
#                      data engineer            3
# Dartmouth            na                       2
# Coquitlam            na                       1
# Concord              analyst                  1
# Cochin               data scientist           2
#                      data engineer            1
#                      analyst                  1
# Chatham              mle                      1
#                      analyst                  1
# Charlottetown        na                       1
# Chalk River          na                       6
# Carp                 analyst                  1
# Candiac              na                       1
# Cambridge            data engineer            3
# Calgary              analyst                 12
#                      na                       3
#                      manager                  1
#                      data scientist           4
#                      data engineer            8
# Burnaby              na                       4
#                      mle                      2
#                      data scientist           2
#                      data engineer            1
#                      analyst                  2
# Burlington           analyst                  1
# Brossard             na                       1
# British Columbia     na                       1
# Brampton             data scientist           6
#                      analyst                  3
#                      data engineer            1
# Boucherville         data scientist           1
#                      analyst                  1

# %%
pd.pivot_table(df[df.title == 'analyst'], index = 'Location', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#                       avg_salary
# Location
# Newmarket             183.000000
# na                    103.500000
# Maple Ridge           103.500000
# Concord                99.000000
# Calgary                96.333333
# Cochin                 95.000000
# Oakville               95.000000
# Boucherville           95.000000
# Moncton                94.500000
# Upper Canada Village   90.500000
# Markham                90.500000
# Mirabel                88.250000
# Regina                 87.000000
# Vancouver              86.326087
# Toronto                85.681818
# Victoria               84.500000
# Mississauga            83.857143
# Montreal               82.500000
# Ottawa                 79.785714
# Saint-Hubert           79.000000
# Burlington             79.000000
# Chatham                79.000000
# London                 79.000000
# Kitchener              78.250000
# Brampton               76.500000
# Richmond               75.500000
# Halifax                75.500000
# Guelph                 75.000000
# Etobicoke              74.000000
# Montréal-Est           74.000000
# North Vancouver        74.000000
# Carp                   74.000000
# Edmonton               74.000000
# Ontario                73.500000
# Saskatoon              72.500000
# Waterloo               72.500000
# Burnaby                64.250000
# Winnipeg               64.000000
# Kingston               63.500000
# Stratford              63.500000
# Hamilton               56.000000
# West Vancouver         56.000000
# Saint-Jérôme           56.000000

# %%
df.columns
# Out:
# Index(['Company Name', 'Competitors', 'Founded', 'Headquarters', 'Industry',
#        'Job Description', 'Job Title', 'Location', 'Rating', 'Revenue',
#        'Salary Estimate', 'Sector', 'Size', 'Type of ownership', 'min_salary',
#        'max_salary', 'avg_salary', 'company', 'headquarters_location',
#        'same_location', 'age', 'python_yn', 'tableau_yn', 'aws_yn', 'spark_yn',
#        'computer_science_yn', 'ml_yn', 'sql_yn', 'excel_yn', 'title',
#        'seniority', 'job_desc_len', 'comp_count'],
#       dtype='object')

# %%
# Rating, Industry, Sector, Revenue, comp_count, python, tableau, spark, aws, computer science,
# excel, job_desc_len, Type of onwership

# %%
df_pivots = df[['Industry', 'Sector', 'Revenue', 'comp_count', 'python_yn', 'computer_science_yn', 'ml_yn',
                'sql_yn','tableau_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'Type of ownership','avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots,index =i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
# Out:
# Industry
#                                          avg_salary
# Industry
# Security Services                        112.500000
# TV Broadcasting & Cable Networks         111.500000
# Chemical Manufacturing                   111.500000
# Financial Transaction Processing         110.500000
# Architectural & Engineering Services     106.444444
# Membership Organisations                 103.500000
# Energy                                   103.500000
# Insurance Agencies & Brokerages          101.375000
# Motor Vehicle Parts & Accessories Shops   99.250000
# Biotech & Pharmaceuticals                 98.241935
# Social Services                           98.000000
# Advertising & Marketing                   96.222222
# Venture Capital & Private Equity          95.250000
# Transportation Management                 95.000000
# Financial Analytics & Research            94.500000
# Music Production & Distribution           92.750000
# Food & Drink Manufacturing                91.142857
# Colleges & Universities                   91.000000
# Electrical & Electronic Manufacturing     90.500000
# IT Services                               90.486486
# Hotel & Resorts                           90.000000
# Health, Beauty & Fitness                  89.750000
# Oil & Gas Services                        89.000000
# -1                                        88.861702
# Video Games                               88.340000
# Education Training Services               87.700000
# Enterprise Software & Network Solutions   87.614583
# Internet                                  87.109375
# Computer Hardware & Software              86.948276
# Lending                                   86.875000
# Industrial Manufacturing                  86.800000
# Government Agencies                       86.500000
# Metal & Mineral Manufacturing             86.500000
# Investment Banking & Asset Management     85.270833
# Healthcare Services & Hospitals           85.150000
# Research & Development                    84.687500
# Banks & Building Societies                82.555556
# Consulting                                81.522727
# Stock Exchanges                           81.500000
# Travel Agencies                           81.500000
# News Outlets                              81.500000
# Staffing & Outsourcing                    81.393939
# Vehicle Dealers                           81.125000
# Department, Clothing, & Shoe Shops        80.500000
# Mining                                    80.200000
# Insurance Operators                       80.181818
# Sporting Goods Shops                      80.166667
# Cable, Internet & Telephone Providers     79.142857
# Transportation Equipment Manufacturing    77.500000
# Telecommunications Services               75.750000
# Aerospace & Defence                       75.375000
# Real Estate                               75.125000
# Rail Freight                              74.000000
# Telecommunications Manufacturing          72.500000
# Accounting                                70.214286
# Building & Construction                   70.166667
# Consumer Electronics & Appliance Shops    67.500000
# Sports & Recreation                       64.000000
# Home Centres & DIY/Hardware Shops         63.500000
# Publishing                                62.666667
# Healthcare Product Manufacturing          60.125000
# Local Councils                            57.500000
# Commercial Equipment Hire                 56.000000
# Legal                                     55.500000
# Media & Entertainment Retail Shops        55.500000
# Sector
#                                   avg_salary
# Sector
# Biotech & Pharmaceuticals          98.241935
# Non-Profits                        98.000000
# Oil, Gas, Energy & Utilities       94.800000
# Consumer Services                  89.750000
# Education                          88.937500
# -1                                 88.861702
# Information Technology             87.908571
# Finance                            87.322581
# Travel & Tourism                   87.166667
# Media                              86.718750
# Business Services                  86.345238
# Insurance                          85.833333
# Healthcare                         85.150000
# Transportation & Logistics         84.500000
# Manufacturing                      84.040000
# Government                         83.277778
# Mining & Metals                    80.200000
# Retail                             79.340000
# Telecommunications                 76.888889
# Aerospace & Defence                75.375000
# Real Estate                        75.125000
# Building, Repair & Maintenance     70.166667
# Accounting & Legal                 68.375000
# Arts, Entertainment & Recreation   64.000000
# Revenue
#                                   avg_salary
# Revenue
# ₹50 to ₹100 million (INR)          99.250000
# ₹100 to ₹500 billion (INR)         94.071429
# ₹10 to ₹50 billion (INR)           90.320312
# ₹5 to ₹10 billion (INR)            89.854167
# Unknown / Non-Applicable           87.844765
# ₹10 to ₹50 million (INR)           87.666667
# -1                                 86.216981
# ₹1 to ₹5 billion (INR)             85.806122
# ₹500+ billion (INR)                84.645669
# ₹500 million to ₹1 billion (INR)   82.300000
# ₹100 to ₹500 million (INR)         80.340000
# ₹50 to ₹100 billion (INR)          79.100000
# Less than ₹10 million (INR)        79.000000
# comp_count
#             avg_salary
# comp_count
# 2            87.704545
# 0            87.363548
# 3            87.174286
# 1            84.000000
# python_yn
#            avg_salary
# python_yn
# 0           87.570552
# 1           87.057398
# computer_science_yn
#                      avg_salary
# computer_science_yn
# 1                     87.589831
# 0                     87.081560
# ml_yn
#        avg_salary
# ml_yn
# 0       87.571910
# 1       86.831502
# sql_yn
#         avg_salary
# sql_yn
# 0        87.464770
# 1        87.106017
# tableau_yn
#             avg_salary
# tableau_yn
# 0            87.984375
# 1            83.454545
# spark_yn
#           avg_salary
# spark_yn
# 0          87.739544
# 1          86.059896
# aws_yn
#         avg_salary
# aws_yn
# 1        91.496552
# 0        86.226003
# excel_yn
#           avg_salary
# excel_yn
# 1          88.508427
# 0          86.092541
# Type of ownership
#                                 avg_salary
# Type of ownership
# Contract                        123.250000
# Self-employed                   103.500000
# Subsidiary or Business Segment   93.203704
# Non-profit Organisation          90.818182
# Government                       87.900000
# Company - Private                87.692416
# Company - Public                 87.042035
# College / University             86.750000
# -1                               86.216981
# Hospital                         79.687500
# Unknown                          78.111111
# Other Organisation               72.083333
# Private Practice / Firm          70.100000
# avg_salary
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-ffbf8dbbfab7> in <module>
#       1 for i in df_pivots.columns:
#       2     print(i)
# ----> 3     print(pd.pivot_table(df_pivots,index =i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      79         values = list(values)
#      80
# ---> 81     grouped = data.groupby(keys, observed=False)
#      82     agged = grouped.agg(aggfunc)
#      83     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# -> 2110     return klass(obj, by, **kwds)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     358                                                     sort=sort,
#     359                                                     observed=observed,
# --> 360                                                     mutated=self.mutated)
#     361
#     362         self.obj = obj
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     600                          observed=observed,
#     601                          in_axis=in_axis)
# --> 602                 if not isinstance(gpr, Grouping) else gpr)
#     603
#     604         groupings.append(ping)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis)
#     320                     t = self.name or str(type(self.grouper))
#     321                     raise ValueError(
# --> 322                         "Grouper for '{}' not 1-dimensional".format(t))
#     323                 self.grouper = self.index.map(self.grouper)
#     324                 if not (hasattr(self.grouper, "__len__") and
#
# ValueError: Grouper for 'avg_salary' not 1-dimensional

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/nltk/corpus/util.py in __load(self)
#      85                 try:
# ---> 86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/data.py in find(resource_name, paths)
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - '/Users/nikhitaputta/nltk_data'
#     - '/Users/nikhitaputta/anaconda3/nltk_data'
#     - '/Users/nikhitaputta/anaconda3/share/nltk_data'
#     - '/Users/nikhitaputta/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-61-c77528177ed4> in <module>
#      12
#      13
# ---> 14 words_filtered = punctuation_stop(words)
#      15
#      16 text = " ".join([ele for ele in words_filtered])
#
# <ipython-input-61-c77528177ed4> in punctuation_stop(text)
#       4     """remove punctuation and stop words"""
#       5     filtered = []
# ----> 6     stop_words = set(stopwords.words('english'))
#       7     word_tokens = word_tokenize(text)
#       8     for w in word_tokens:
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/corpus/util.py in __getattr__(self, attr)
#     121             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     122
# --> 123         self.__load()
#     124         # This looks circular, but its not, since __load() changes our
#     125         # __class__ to something new:
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/corpus/util.py in __load(self)
#      86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
# ---> 88                     raise e
#      89
#      90         # Load the corpus.
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/corpus/util.py in __load(self)
#      81         else:
#      82             try:
# ---> 83                 root = nltk.data.find('{}/{}'.format(self.subdir, self.__name))
#      84             except LookupError as e:
#      85                 try:
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/data.py in find(resource_name, paths)
#     699     sep = '*' * 70
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#     703
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - '/Users/nikhitaputta/nltk_data'
#     - '/Users/nikhitaputta/anaconda3/nltk_data'
#     - '/Users/nikhitaputta/anaconda3/share/nltk_data'
#     - '/Users/nikhitaputta/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/Users/nikhitaputta/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/nikhitaputta/anaconda3/lib/python3.7/site-packages/nltk/downloader.py", line 2117, in run
#     for msg in self.data_server.incr_download(self.items):
#   File "/Users/nikhitaputta/anaconda3/lib/python3.7/site-packages/nltk/downloader.py", line 630, in incr_download
#     for msg in self._download_list(info_or_id, download_dir, force):
#   File "/Users/nikhitaputta/anaconda3/lib/python3.7/site-packages/nltk/downloader.py", line 676, in _download_list
#     for msg in self.incr_download(item, download_dir, force):
#   File "/Users/nikhitaputta/anaconda3/lib/python3.7/site-packages/nltk/downloader.py", line 644, in incr_download
#     for msg in self.incr_download(info.children, download_dir, force):
#   File "/Users/nikhitaputta/anaconda3/lib/python3.7/site-packages/nltk/downloader.py", line 630, in incr_download
#     for msg in self._download_list(info_or_id, download_dir, force):
#   File "/Users/nikhitaputta/anaconda3/lib/python3.7/site-packages/nltk/downloader.py", line 676, in _download_list
#     for msg in self.incr_download(item, download_dir, force):
#   File "/Users/nikhitaputta/anaconda3/lib/python3.7/site-packages/nltk/downloader.py", line 650, in incr_download
#     for msg in self._download_package(info, download_dir, force):
#   File "/Users/nikhitaputta/anaconda3/lib/python3.7/site-packages/nltk/downloader.py", line 708, in _download_package
#     os.mkdir(download_dir)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/share/nltk_data'
